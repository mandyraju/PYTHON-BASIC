# %% [markdown]
# Theory questions
# Q1. What is NumPy, and why is it widely used in Python
#
# ans. Numpy is a vast libraby used in pyhton. it stands for mumerical python
# NumPy is a Python library for working with arrays (grids of numbers). It's used because it makes math and data calculations easy and fast, especially for big datasets.
#
# Q2. A How does broadcasting work in NumPy
#
# Broadcasting lets NumPy perform math operations on arrays of different shapes by automatically expanding the smaller array so the operation makes sense.
# For instance, you can add a scalar to an array or add arrays with compatible shapes (e.g., a 3x1 and a 1x4 array) by aligning them along their dimensions.
#
# Q3. What is a Pandas DataFrame
#
# Ans. A DataFrame is like a spreadsheet or table in Python. It holds data in rows and columns, making it easy to organize, analyze, and manipulate.
#
# Q4.Explain the use of the groupby() method in Pandas
#
# ANS. The groupby() method in Pandas is used to split data into groups based on specified criteria (e.g., column values) apply a function (like mean, sum, count), and combine results. It is useful for aggregating and summarizing data based on one or more key
#
# Q5. Why is Seaborn preferred for statistical visualizations
#
# Ans. Seaborn makes it easy to create attractive graphs and charts that show patterns, trends, and relationships in data. It includes built-in styles and color themes for better visuals.
#
# Q6.What are the differences between NumPy arrays and Python lists
#
# Ans. NumPy arrays store elements of the same type; lists can store different types.
#
# NumPy arrays are faster and take up less space.
#
# Arrays support advanced math operations, but lists don't.
#
# Q7. What is a heatmap, and when should it be used
#
# Ans. A heatmap is a chart that uses colors to show numbers or values. It's useful to spot patterns or high/low values in data tables
#
# Q8. What does the term “vectorized operation” mean in NumPy
#
# ANS. Vectorized operations allow you to perform calculations on entire arrays, not one element at a time. This is faster and needs less code.
#
# Q9. How does Matplotlib differ from Plotly
#
# Ans. Matplotlib is simple and traditional, mainly for static images.
#
# Plotly makes interactive, web-friendly charts with tooltips and zoom features.
#
# Q10. What is the significance of hierarchical indexing in Pandas
#
# Ans. Hierarchical indexing means having multiple levels of row or column labels, letting you handle complex datasets with ease.
#
# Q11. What is the role of Seaborn’s pairplot() function
#
# Ans. The pairplot() function creates multiple scatterplots for all pairs of columns, helping to see relationships between variables.
#
# Q12. What is the purpose of the describe() function in Pandas
#
# Ans. describe() gives quick summary statistics like mean, median, and max for columns in a DataFrame.
#
# Q13.  Why is handling missing data important in Pandas
#
# Ans.Missing data can impact the accuracy and validity of analysis and models. Pandas provides flexible tools (e.g., isnull(), dropna(), fillna()) to detect, remove, or impute missing values, helping ensure data quality and reliable outcomes
#
# Q14. What are the benefits of using Plotly for data visualization
#
# Ans. Highly interactive plots (tooltips, zoom, filtering)
#
# Web-ready, embeddable in web apps and dashboards
#
# Handles large datasets and live updating
#
# Supports animations and 3D visualizations
#
# Q15. How does NumPy handle multidimensional arrays
#
# Ans. NumPy provides the ndarray object for n-dimensional arrays (tensors). These arrays support fast, elementwise operations with a consistent API, advanced slicing/indexing, and memory-efficient storage
#
# Q16. What is the role of Bokeh in data visualization
#
# ans. Bokeh is a Python library for creating interactive, web-enabled data visualizations. It excels at building dashboards and complex interactivity in web browsers with large or streaming datasets.
#
# Q17.  Explain the difference between apply() and map() in Pandas
#
# Ans. map(): Used for transforming values in a Series using a function or mapping dictionary; elementwise.
#
# apply(): Can be used with both Series and DataFrame to apply functions along an axis or elementwise; more flexible and powerful.
#
# Q18. What are some advanced features of NumPy
#
# ans. Fast linear algebra and statistics
#
# Random number generation
#
# Shape reshaping and broadcasting
#
# Fourier transforms and filtering
#
# Q19. How does Pandas simplify time series analysis
#
# Ans. Pandas can handle dates and times, letting you easily resample, shift, and analyze time-based data.
#
# Q20. What is the role of a pivot table in Pandas
#
# ans. Pivot tables let you quickly organize and summarize data by different categories, making analysis easier.
#
# Q21. Why is NumPy’s array slicing faster than Python’s list slicing
#
# Asn. NumPy arrays store data more efficiently in memory and perform slicing using optimized C code, so it's much faster than lists.
#
# Q22. A What are some common use cases for Seaborn
#
# Ans. Plotting bar charts, box plots, and scatter plots
#
# Showing data distributions
#
# Visualizing correlations and trends in data
#
# Making publication-quality statistical graphs

# %%
# How do you create a 2D NumPy array and calculate the sum of each row

import numpy as np
my_arry = np.array([[1,2],[2,4]])

sum_arry = my_arry.sum(axis=1)
print("Array:\n", my_arry)
print("thsi is the sum of each row", sum_arry)
# Out:
# Array:
#  [[1 2]
#  [2 4]]
# thsi is the sum of each row [3 6]

# %%
#Q2 Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd

df = pd.DataFrame({'A': [10, 20, 30], 'B': [1, 2, 3]})
mean_A = df['A'].mean()
print("Mean of column A:", mean_A)
# Out:
# Mean of column A: 20.0

# %%
#Q3. Create a scatter plot using Matplotlib

import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 5, 7, 12, 9])
plt.scatter(x, y)
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Sample Scatter Plot")
plt.show()

# %%
#Q4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
#Q5 A Generate a bar plot using PlotlyA

import plotly.express as px

data = {'Fruits': ['Apple', 'Banana', 'Cherry'],
        'Quantity': [10, 15, 7]}
df = pd.DataFrame(data)
fig = px.bar(df, x='Fruits', y='Quantity', title='fruit quantity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Q6 Create a DataFrame and add a new column based on an existing column
import pandas as pd

df = pd.DataFrame({'value': [1, 2, 3]})
df['double'] = df['value'] *2
df
# Out:
#    value  double
# 0      1       2
# 1      2       4
# 2      3       6

# %%
#Q7. Write a program to perform element-wise multiplication of two NumPy arrays

import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = a * b
print("Result:", c)
# Out:
# Result: [ 4 10 18]

# %%
#Q8. Create a line plot with multiple lines using Matplotlib

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [2, 3, 4, 5, 6]
plt.plot(x, y1, label='Squares')
plt.plot(x, y2, label='Linear')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Multiple Line Plot')
plt.legend()
plt.show()

# %%
#Q9.Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

import pandas as pd

df = pd.DataFrame({'score': [50, 70, 90, 60]})
filtered = df[df['score'] > 65]
print(filtered)
# Out:
#    score
# 1     70
# 2     90

# %%
#Q10. Create a histogram using Seaborn to visualize a distribution

import seaborn as sns
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 4, 4, 5]
sns.histplot(data, bins=5, kde=True)
plt.title("Distribution Histogram")
plt.show()

# %%
#Q11. Perform matrix multiplication using NumPy

import numpy as np

a = np.array([[1, 2],
              [3, 4]])
b = np.array([[5, 6],
              [7, 8]])
result = np.dot(a, b)
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
#Q12. Use Pandas to load a CSV file and display its first 5 rows

from google.colab import files

uploaded = files.upload()

import pandas as pd

try:
    df = pd.read_csv('vo_comp.csv', encoding='latin-1')
    print(df.head())
except UnicodeDecodeError:
    print("Could not decode the file with 'latin-1' encoding. Please try a different encoding.")
# Out:
#      <input type="file" id="files-d9261718-1810-4567-b766-30759cac68a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9261718-1810-4567-b766-30759cac68a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Q13. Create a 3D scatter plot using Plotly.
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    'x': [1,2,3,4,5],
    'y': [10,11,12,13,14],
    'z': [5,7,6,8,9]
})
fig = px.scatter_3d(df, x='x', y='y', z='z', title='3D Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# THanks
